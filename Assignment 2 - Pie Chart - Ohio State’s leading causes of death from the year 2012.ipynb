# %%
import matplotlib.pyplot as plt

# %%
Percentile = ['5','4','2','1','62','26']
cause_of_deaths = ['Unintetional Injuries', 'Alzheimers', 'Infuenza and Pneumonia', 'Sepsis','Chronic Disease','Others']

# %%
plt.pie(Percentile,labels=cause_of_deaths)
plt.title("Ohio - Cause of Deaths")
plt.show()
